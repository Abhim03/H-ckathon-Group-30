# %% [markdown]
# ## Preprocessing
#
# ### Group 30

# %% [markdown]
# ### Imports and General Setup

# %%
# Bibliothèques de base
import os
import warnings

import numpy as np
import pandas as pd

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Outils de machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer

# Pour plus tard : modèles de régression (exemples)
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Configuration affichage
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 100)
sns.set(style="whitegrid")

print("Imports OK.")
# Out:
# Imports OK.

# %% [markdown]
# ### Step 1 – Dataset Loading and Initial Exploration

# %%
import pandas as pd

# Replace this path with the actual file path on your side
data_path = "X_train.csv"

# Load the dataset
df = pd.read_csv(data_path)

# Shape of the dataset
print(f"Dataset shape: {df.shape}")  # (rows, columns)

# List of columns and their types
print("\nColumn Info:")
print(df.dtypes)

# Display the first 5 rows
print("\nFirst 5 rows:")
display(df.head())

# Quick summary of missing values
print("\nMissing values per column:")
print(df.isnull().sum().sort_values(ascending=False).head(10))  # top 10

# Basic statistics
print("\nDescriptive statistics (numeric):")
display(df.describe())
# Out:
# Dataset shape: (1172086, 307)
#
# Column Info:
# Unnamed: 0                    int64
# Year                          int64
# CNT                          object
# CNTRYID                     float64
# CNTSCHID                    float64
#                              ...
# science_q15_total_timing    float64
# science_q16_total_timing    float64
# science_q17_total_timing    float64
# science_q18_total_timing    float64
# science_q19_total_timing    float64
# Length: 307, dtype: object
#
# First 5 rows:
#    Unnamed: 0  Year  CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen  \
# 0      384002  2022  NLD    528.0  52800132.0  52801144.0  08MS   52800
# 1     1118072  2018  QAZ     31.0   3100106.0   3100424.0  07MS    3100
# 2      845454  2018  FRA    250.0  25000010.0  25005207.0  07MS   25000
# 3     1728613  2015  QES    971.0  97100240.0  97127584.0  06MS   72400
# 4     1083243  2018  PHL    608.0  60800071.0  60802698.0  07MS   60800
#
#    STRATUM  SUBNATIO  OECD  ADMINMODE  LANGTEST_QQQ  LANGTEST_COG  \
# 0    NLD06   5280000   1.0        2.0         322.0         322.0
# 1  QAZ0101    310000   0.0        2.0         803.0         803.0
# 2  FRA0101   2500000   1.0        2.0         493.0         493.0
# 3  ESP1633   7241600   2.0        2.0         156.0         156.0
# 4  PHL0011   6080000   0.0        2.0         313.0         313.0
#
#    LANGTEST_PAQ  Option_CT  Option_FL  Option_ICTQ  Option_WBQ  Option_PQ  \
# 0           NaN        1.0        1.0          0.0         1.0        0.0
# 1           NaN        NaN        NaN          NaN         NaN        NaN
# 2           NaN        NaN        NaN          NaN         NaN        NaN
# 3           NaN        NaN        1.0          1.0         NaN        1.0
# 4           NaN        NaN        NaN          NaN         NaN        NaN
#
#    Option_TQ  Option_UH  ST001D01T  ST003D02T  ST003D03T  ST004D01T  EFFORT1  \
# 0        0.0        1.0       10.0        2.0     2007.0        1.0      8.0
# 1        NaN        NaN       10.0       11.0     2002.0        2.0      7.0
# 2        NaN        NaN       10.0        5.0     2002.0        1.0      NaN
# 3        1.0        0.0       10.0        3.0     1999.0        2.0      NaN
# 4        NaN        NaN        8.0        9.0     2002.0        1.0     10.0
#
#    EFFORT2   OCOD1   OCOD2   OCOD3    AGE  GRADE  ISCEDP  IMMIG   COBN_S  \
# 0      8.0  3256.0  2212.0  9999.0  15.75    0.0   244.0    2.0  52800.0
# 1      6.0  2330.0  9313.0     0.0  15.42    0.0     NaN    NaN   3100.0
# 2      NaN  3323.0  3322.0  7512.0  16.00    0.0     NaN    NaN  25000.0
# 3      NaN     NaN     NaN     NaN  16.17    NaN     NaN    1.0      NaN
# 4     10.0  9701.0  7132.0  2161.0  15.50   -1.0     NaN    NaN  60800.0
#
#    MISSSC  MATHEASE  WB153  ST253  ST311  WB165  IC171  ST038  IC180  \
# 0     0.0       0.0    2.5    1.0   3.25    1.0    0.0    0.0    0.0
# 1     NaN       NaN    NaN    NaN    NaN    0.0    0.0    0.0    NaN
# 2     NaN       NaN    NaN    NaN    NaN    0.0    3.5    0.0    NaN
# 3     NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN       NaN    NaN    NaN    NaN    0.0    0.0    6.0    NaN
#
#       ST255  ST350     ST034     FL162  PA195  ...  reading_q6_total_timing  \
# 0  0.666667    0.0  2.333333  3.666667    0.0  ...                      NaN
# 1  0.200000    NaN  2.000000       NaN    NaN  ...              8368.284180
# 2  0.600000    NaN  2.000000       NaN    NaN  ...             39792.332031
# 3       NaN    NaN       NaN       NaN    NaN  ...            114817.335938
# 4  0.200000    NaN  1.000000       NaN    NaN  ...              4223.181152
#
#    reading_q7_total_timing  reading_q8_total_timing  reading_q9_total_timing  \
# 0                      NaN                      NaN                      NaN
# 1            112711.000000             69975.710938                      NaN
# 2             92942.984375             82727.664062                      NaN
# 3             81293.335938             59014.332031            140646.328125
# 4            106763.335938             41324.500000             88674.000000
#
#    reading_q10_total_timing  reading_q11_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    reading_q12_total_timing  reading_q13_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    reading_q14_total_timing  reading_q15_total_timing  math_q1_total_timing  \
# 0                       NaN                       NaN               18736.0
# 1                       NaN                       NaN               50234.0
# 2                       NaN                       NaN                   NaN
# 3                       NaN                       NaN                   NaN
# 4                       NaN                       NaN              137692.0
#
#    math_q2_total_timing  math_q3_total_timing  math_q4_total_timing  \
# 0              23055.25             162720.00         110641.333333
# 1              80788.00              48059.00         116718.000000
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4              36046.00              43095.75          82282.500000
#
#    math_q5_total_timing  math_q6_total_timing  math_q7_total_timing  \
# 0          96368.333333               71813.5          98875.000000
# 1          61003.000000               34117.0          56901.667969
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4         121010.500000              191303.0          77024.335938
#
#    math_q8_total_timing  math_q9_total_timing  math_q10_total_timing  \
# 0          63689.400000          37232.000000           88274.666667
# 1          76615.000000          21500.333984           27087.000000
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4         197619.671875          64659.667969                    NaN
#
#    math_q11_total_timing  math_q12_total_timing  math_q13_total_timing  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    math_q14_total_timing  math_q15_total_timing  math_q16_total_timing  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    math_q17_total_timing  math_q18_total_timing  math_q19_total_timing  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    math_q20_total_timing  math_q21_total_timing  science_q1_total_timing  \
# 0                    NaN                    NaN             84299.333333
# 1                    NaN                    NaN                      NaN
# 2                    NaN                    NaN             81443.664062
# 3                    NaN                    NaN             62224.667969
# 4                    NaN                    NaN                      NaN
#
#    science_q2_total_timing  science_q3_total_timing  science_q4_total_timing  \
# 0             90156.000000                 66612.00                  73547.6
# 1                      NaN                      NaN                      NaN
# 2            190243.406250                 36257.00                 148073.5
# 3             83289.664062                 91510.75                 100649.5
# 4                      NaN                      NaN                      NaN
#
#    science_q5_total_timing  science_q6_total_timing  science_q7_total_timing  \
# 0             68912.000000             56623.250000            104190.500000
# 1                      NaN                      NaN                      NaN
# 2              2121.249756             90540.335938             57954.000000
# 3             82378.500000             74348.250000             91230.664062
# 4                      NaN                      NaN                      NaN
#
#    science_q8_total_timing  science_q9_total_timing  science_q10_total_timing  \
# 0                132623.25            105785.666667                       NaN
# 1                      NaN                      NaN                       NaN
# 2                 84633.00             45332.000000                   87686.5
# 3                 49789.00             37855.000000                       NaN
# 4                      NaN                      NaN                       NaN
#
#    science_q11_total_timing  science_q12_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                  13164.75               1187.199951
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    science_q13_total_timing  science_q14_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    science_q15_total_timing  science_q16_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    science_q17_total_timing  science_q18_total_timing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    science_q19_total_timing
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 307 columns]
# Missing values per column:
# math_q18_average_score       1172086
# math_q19_average_score       1172086
# math_q20_average_score       1172086
# math_q21_average_score       1172086
# math_q21_total_timing        1172086
# science_q19_total_timing     1172085
# math_q18_total_timing        1172085
# math_q17_average_score       1172085
# science_q13_average_score    1172085
# science_q14_average_score    1172085
# dtype: int64
#
# Descriptive statistics (numeric):
#          Unnamed: 0          Year       CNTRYID      CNTSCHID      CNTSTUID  \
# count  1.172086e+06  1.172086e+06  1.172086e+06  1.172086e+06  1.172086e+06
# mean   8.788127e+05  2.018517e+03  4.494376e+02  4.494433e+07  4.492926e+07
# std    5.075340e+05  2.835234e+00  2.729180e+02  2.729202e+07  2.726077e+07
# min    0.000000e+00  2.015000e+03  8.000000e+00  8.000010e+05  8.000010e+05
# 25%    4.390612e+05  2.015000e+03  2.030000e+02  2.030036e+07  2.030966e+07
# 50%    8.787835e+05  2.018000e+03  4.110000e+02  4.110018e+07  4.110402e+07
# 75%    1.318404e+06  2.022000e+03  7.030000e+02  7.030026e+07  7.030590e+07
# max    1.758128e+06  2.022000e+03  9.830000e+02  9.830081e+07  9.832912e+07
#
#              NatCen      SUBNATIO          OECD     ADMINMODE  LANGTEST_QQQ  \
# count  1.172086e+06  1.172086e+06  1.172086e+06  1.172086e+06  1.156728e+06
# mean   4.321244e+04  4.437437e+06  5.213278e-01  1.912332e+00  3.136003e+02
# std    2.583040e+04  2.655083e+06  5.403367e-01  2.828123e-01  1.556093e+02
# min    8.000000e+02  8.000000e+04  0.000000e+00  1.000000e+00  1.130000e+02
# 25%    1.910000e+04  2.030000e+06  0.000000e+00  2.000000e+00  1.560000e+02
# 50%    4.100000e+04  4.110000e+06  1.000000e+00  2.000000e+00  3.130000e+02
# 75%    7.020000e+04  7.030000e+06  1.000000e+00  2.000000e+00  4.420000e+02
# max    8.600000e+04  9.830000e+06  2.000000e+00  2.000000e+00  9.980000e+02
#
#        LANGTEST_COG   LANGTEST_PAQ      Option_CT      Option_FL  \
# count  1.172086e+06  190244.000000  412647.000000  760766.000000
# mean   3.139330e+02     252.481324       0.814413       0.327858
# std    1.574370e+02     134.027532       0.388774       0.469433
# min    1.130000e+02     118.000000       0.000000       0.000000
# 25%    1.560000e+02     156.000000       1.000000       0.000000
# 50%    3.130000e+02     232.000000       1.000000       0.000000
# 75%    4.420000e+02     313.000000       1.000000       1.000000
# max    9.980000e+02     998.000000       1.000000       1.000000
#
#          Option_ICTQ     Option_WBQ      Option_PQ      Option_TQ  \
# count  760766.000000  412647.000000  760766.000000  760766.000000
# mean        0.669643       0.219485       0.228988       0.300092
# std         0.470342       0.413899       0.420182       0.458298
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#            Option_UH     ST001D01T     ST003D02T     ST003D03T     ST004D01T  \
# count  760766.000000  1.172086e+06  1.140384e+06  1.156567e+06  1.172037e+06
# mean        0.160316  1.141946e+01  6.571160e+00  2.002591e+03  1.500241e+00
# std         0.366899  1.227383e+01  3.422694e+00  2.848639e+00  5.000002e-01
# min         0.000000  7.000000e+00  1.000000e+00  1.999000e+03  1.000000e+00
# 25%         0.000000  9.000000e+00  4.000000e+00  1.999000e+03  1.000000e+00
# 50%         0.000000  1.000000e+01  7.000000e+00  2.002000e+03  2.000000e+00
# 75%         0.000000  1.000000e+01  1.000000e+01  2.006000e+03  2.000000e+00
# max         1.000000  9.900000e+01  1.200000e+01  2.007000e+03  2.000000e+00
#
#              EFFORT1        EFFORT2          OCOD1          OCOD2  \
# count  690553.000000  684199.000000  823967.000000  823967.000000
# mean        7.824746       9.029611    5866.949590    5759.624446
# std         1.887745       1.604270    3414.843082    3400.414809
# min         1.000000       1.000000       0.000000       0.000000
# 25%         7.000000       9.000000    2411.000000    2411.000000
# 50%         8.000000      10.000000    5223.000000    6121.000000
# 75%         9.000000      10.000000    9701.000000    9329.000000
# max        10.000000      10.000000    9999.000000    9999.000000
#
#                OCOD3           AGE          GRADE         ISCEDP  \
# count  823967.000000  1.168818e+06  805483.000000  412645.000000
# mean     5031.857720  1.579184e+01      -0.139855     312.920685
# std      3607.643589  2.908386e-01       0.612310      47.747457
# min         0.000000  1.508000e+01      -4.000000     244.000000
# 25%      2212.000000  1.558000e+01       0.000000     244.000000
# 50%      3153.000000  1.575000e+01       0.000000     344.000000
# 75%      9705.000000  1.600000e+01       0.000000     344.000000
# max      9999.000000  1.642000e+01       4.000000     453.000000
#
#                IMMIG         COBN_S         MISSSC       MATHEASE  \
# count  710868.000000  823967.000000  350864.000000  340810.000000
# mean        1.179683  118399.332157       0.101891       0.103615
# std         0.515642  254588.376204       0.302506       0.304761
# min         1.000000     400.000000       0.000000       0.000000
# 25%         1.000000   21400.000000       0.000000       0.000000
# 50%         1.000000   44200.000000       0.000000       0.000000
# 75%         1.000000   72405.000000       0.000000       0.000000
# max         3.000000  999999.000000       1.000000       1.000000
#
#                WB153          ST253          ST311          WB165  \
# count  412647.000000  412647.000000  412647.000000  823967.000000
# mean        0.420411       0.726139       2.309725       0.086288
# std         1.006695       0.303579       1.285723       0.260037
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.571429       1.750000       0.000000
# 50%         0.000000       0.857143       2.500000       0.000000
# 75%         0.000000       1.000000       3.250000       0.000000
# max         5.000000       1.000000       6.500000       1.000000
#
#                IC171          ST038          IC180          ST255  \
# count  823967.000000  823967.000000  412647.000000  823967.000000
# mean        1.846118       0.670083       2.083616       0.388077
# std         1.929383       1.133211       2.217686       0.278662
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.166667
# 50%         1.600000       0.000000       1.000000       0.400000
# 75%         3.583333       1.000000       4.000000       0.600000
# max         8.750000       9.000000       8.000000       1.000000
#
#                ST350          ST034          FL162          PA195  \
# count  412647.000000  823967.000000  412647.000000  412647.000000
# mean        0.148537       2.313571       0.681207       0.061641
# std         0.289102       1.032723       1.395165       0.180407
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       2.000000       0.000000       0.000000
# 50%         0.000000       2.333333       0.000000       0.000000
# 75%         0.000000       3.000000       0.000000       0.000000
# max         1.000000       6.000000       6.000000       1.000000
#
#                ST330          FL169          ST230  ...  \
# count  412647.000000  412647.000000  412647.000000  ...
# mean        1.328697       1.358509       0.576880  ...
# std         1.383181       2.485783       0.349743  ...
# min         0.000000       0.000000       0.000000  ...
# 25%         0.000000       0.000000       0.333333  ...
# 50%         1.000000       0.000000       0.666667  ...
# 75%         2.000000       0.000000       1.000000  ...
# max         5.000000      10.000000       1.000000  ...
#
#        reading_q6_total_timing  reading_q7_total_timing  \
# count             6.030370e+05             5.304950e+05
# mean              4.923457e+04             6.144251e+04
# std               4.361412e+04             4.739884e+04
# min               1.311682e+00             6.637619e-01
# 25%               6.773726e+03             3.582380e+04
# 50%               4.664367e+04             5.681300e+04
# 75%               7.369666e+04             8.044921e+04
# max               2.723678e+06             1.390472e+07
#
#        reading_q8_total_timing  reading_q9_total_timing  \
# count             3.366750e+05             1.005430e+05
# mean              6.423997e+04             6.849181e+04
# std               4.295397e+04             1.109829e+05
# min               1.424364e+00             1.793571e+00
# 25%               3.991162e+04             3.968841e+04
# 50%               5.936617e+04             6.010933e+04
# 75%               8.131058e+04             8.556143e+04
# max               6.342214e+06             3.193341e+07
#
#        reading_q10_total_timing  reading_q11_total_timing  \
# count                941.000000                139.000000
# mean               53477.077612              30183.621353
# std                36750.877208              31511.685071
# min                  567.000000                526.571411
# 25%                25853.572266               5190.333252
# 50%                52091.000000              17597.666000
# 75%                76034.289062              46319.666000
# max               296814.656250             173724.328125
#
#        reading_q12_total_timing  reading_q13_total_timing  \
# count                 73.000000                 41.000000
# mean               32525.305947              30055.001529
# std                35730.716902              27519.775756
# min                 1123.000000               1750.000000
# 25%                 6161.428711               9127.333008
# 50%                25053.000000              24712.285156
# 75%                42826.667969              37315.714844
# max               173167.000000             113009.500000
#
#        reading_q14_total_timing  reading_q15_total_timing  \
# count                 12.000000                  3.000000
# mean               43336.649398              11198.571115
# std                54722.129742              13395.880274
# min                 5179.200000               3002.857143
# 25%                 9544.928589               3469.142805
# 50%                21963.213867               3935.428467
# 75%                49907.416992              15296.428101
# max               189449.281250              26657.427734
#
#        math_q1_total_timing  math_q2_total_timing  math_q3_total_timing  \
# count          6.793450e+05          6.787310e+05          6.774830e+05
# mean           9.256004e+04          8.446210e+04          9.225280e+04
# std            1.088489e+05          8.118865e+04          9.661444e+04
# min            6.262500e+02          6.453333e+02          5.953333e+02
# 25%            4.843433e+04          4.580900e+04          5.145750e+04
# 50%            7.765100e+04          7.159933e+04          7.981300e+04
# 75%            1.185250e+05          1.083062e+05          1.167078e+05
# max            4.987375e+07          2.270718e+07          3.927759e+07
#
#        math_q4_total_timing  math_q5_total_timing  math_q6_total_timing  \
# count          6.711490e+05          6.583870e+05          6.414750e+05
# mean           9.382821e+04          9.449319e+04          1.021636e+05
# std            8.265136e+04          1.167659e+05          1.383660e+05
# min            6.406667e+02          2.580000e+02          6.786667e+02
# 25%            5.103667e+04          4.964900e+04          5.163667e+04
# 50%            7.951700e+04          8.007000e+04          8.626666e+04
# 75%            1.189437e+05          1.201132e+05          1.322478e+05
# max            2.503213e+07          5.459048e+07          8.513372e+07
#
#        math_q7_total_timing  math_q8_total_timing  math_q9_total_timing  \
# count          6.306690e+05          6.086540e+05          5.868940e+05
# mean           1.001498e+05          9.681770e+04          9.239146e+04
# std            8.877246e+04          7.038496e+04          1.287024e+05
# min            7.783333e+02          7.040000e+02          7.440000e+02
# 25%            5.139300e+04          5.125262e+04          4.752681e+04
# 50%            8.505250e+04          8.394038e+04          7.820900e+04
# 75%            1.299010e+05          1.259260e+05          1.207695e+05
# max            2.847083e+07          7.165996e+06          7.547209e+07
#
#        math_q10_total_timing  math_q11_total_timing  math_q12_total_timing  \
# count           5.185320e+05           4.408200e+05           3.038110e+05
# mean            9.136022e+04           9.005534e+04           8.965285e+04
# std             9.328495e+04           8.544431e+04           6.021362e+04
# min             7.793333e+02           9.100000e+02           1.120000e+03
# 25%             4.717000e+04           4.870700e+04           5.222675e+04
# 50%             7.834025e+04           7.909017e+04           8.080700e+04
# 75%             1.190182e+05           1.167162e+05           1.151303e+05
# max             4.412312e+07           2.523702e+07           6.131383e+06
#
#        math_q13_total_timing  math_q14_total_timing  math_q15_total_timing  \
# count           1.824880e+05           8.817100e+04           3.489300e+04
# mean            8.686860e+04           8.355656e+04           8.575860e+04
# std             5.619075e+04           5.044238e+04           5.275948e+04
# min             1.051000e+03           9.610000e+02           1.396000e+03
# 25%             5.064700e+04           4.989150e+04           5.662800e+04
# 50%             7.730067e+04           7.603650e+04           7.581300e+04
# 75%             1.111551e+05           1.072028e+05           1.032210e+05
# max             3.747904e+06           1.281638e+06           3.894162e+06
#
#        math_q16_total_timing  math_q17_total_timing  math_q18_total_timing  \
# count           2.295600e+04                    1.0                    1.0
# mean            1.017054e+05                13121.0                 4799.0
# std             6.584326e+04                    NaN                    NaN
# min             1.107000e+03                13121.0                 4799.0
# 25%             6.443088e+04                13121.0                 4799.0
# 50%             9.522600e+04                13121.0                 4799.0
# 75%             1.299078e+05                13121.0                 4799.0
# max             5.207376e+06                13121.0                 4799.0
#
#        math_q19_total_timing  math_q20_total_timing  math_q21_total_timing  \
# count               1.000000                    1.0                    0.0
# mean            34486.333333                19540.0                    NaN
# std                      NaN                    NaN                    NaN
# min             34486.333333                19540.0                    NaN
# 25%             34486.333333                19540.0                    NaN
# 50%             34486.333333                19540.0                    NaN
# 75%             34486.333333                19540.0                    NaN
# max             34486.333333                19540.0                    NaN
#
#        science_q1_total_timing  science_q2_total_timing  \
# count             6.426680e+05             6.422500e+05
# mean              7.175243e+04             7.771194e+04
# std               5.808780e+04             5.038652e+04
# min               4.466667e+02             4.020000e+02
# 25%               4.187473e+04             4.659031e+04
# 50%               6.521850e+04             7.007767e+04
# 75%               9.131912e+04             9.864100e+04
# max               1.831746e+07             3.837512e+06
#
#        science_q3_total_timing  science_q4_total_timing  \
# count             6.411090e+05             6.387540e+05
# mean              7.969735e+04             7.647816e+04
# std               6.919762e+04             5.677515e+04
# min               5.045000e+02             5.127500e+02
# 25%               4.384625e+04             4.223856e+04
# 50%               7.331566e+04             6.939158e+04
# 75%               1.049775e+05             1.002229e+05
# max               1.953485e+07             1.505885e+07
#
#        science_q5_total_timing  science_q6_total_timing  \
# count             6.294370e+05             6.110490e+05
# mean              6.886065e+04             6.847547e+04
# std               4.422224e+04             4.277651e+04
# min               2.630000e+02             2.690000e+02
# 25%               4.124800e+04             4.294333e+04
# 50%               6.244867e+04             6.302367e+04
# 75%               8.817075e+04             8.679650e+04
# max               6.547292e+06             9.237028e+06
#
#        science_q7_total_timing  science_q8_total_timing  \
# count             5.861210e+05             5.553690e+05
# mean              6.560120e+04             6.890748e+04
# std               5.851337e+04             5.445168e+04
# min               4.476667e+02             4.140000e+02
# 25%               4.069050e+04             4.152300e+04
# 50%               5.919500e+04             6.163250e+04
# 75%               8.268566e+04             8.714775e+04
# max               2.513825e+07             1.971142e+07
#
#        science_q9_total_timing  science_q10_total_timing  \
# count             4.431870e+05              3.307340e+05
# mean              6.574302e+04              6.442787e+04
# std               4.870803e+04              5.484239e+04
# min               4.777500e+02              3.267500e+02
# 25%               4.129325e+04              4.120906e+04
# 50%               5.946300e+04              5.935129e+04
# 75%               8.195834e+04              8.155475e+04
# max               1.098374e+07              1.550666e+07
#
#        science_q11_total_timing  science_q12_total_timing  \
# count              2.221060e+05              4.514500e+04
# mean               6.821547e+04              4.255167e+04
# std                8.608163e+04              3.316757e+04
# min                4.502000e+02              4.686000e+02
# 25%                4.287625e+04              2.255100e+04
# 50%                6.240938e+04              4.053520e+04
# 75%                8.568938e+04              5.618780e+04
# max                2.483809e+07              1.336106e+06
#
#        science_q13_total_timing  science_q14_total_timing  \
# count                  1.000000                       1.0
# mean               73159.335938                   47928.5
# std                         NaN                       NaN
# min                73159.335938                   47928.5
# 25%                73159.335938                   47928.5
# 50%                73159.335938                   47928.5
# 75%                73159.335938                   47928.5
# max                73159.335938                   47928.5
#
#        science_q15_total_timing  science_q16_total_timing  \
# count                       1.0                       1.0
# mean                    53570.5                  118881.0
# std                         NaN                       NaN
# min                     53570.5                  118881.0
# 25%                     53570.5                  118881.0
# 50%                     53570.5                  118881.0
# 75%                     53570.5                  118881.0
# max                     53570.5                  118881.0
#
#        science_q17_total_timing  science_q18_total_timing  \
# count                      1.00                  1.000000
# mean                  119068.25             167551.796875
# std                         NaN                       NaN
# min                   119068.25             167551.796875
# 25%                   119068.25             167551.796875
# 50%                   119068.25             167551.796875
# 75%                   119068.25             167551.796875
# max                   119068.25             167551.796875
#
#        science_q19_total_timing
# count                      1.00
# mean                   59299.25
# std                         NaN
# min                    59299.25
# 25%                    59299.25
# 50%                    59299.25
# 75%                    59299.25
# max                    59299.25
#
# [8 rows x 304 columns]

# %% [markdown]
# ### Column Overview

# %%
# Aperçu des noms de colonnes
print("Total columns:", len(df.columns))
print("\ncolumn names:")
print(df.columns.tolist())

# Séparation colonnes numériques / catégorielles
num_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
cat_cols = df.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

print(f"\nNumeric columns: {len(num_cols)}")
print(num_cols[:10])  # aperçu

print(f"\nCategorical columns: {len(cat_cols)}")
print(cat_cols[:10])  # aperçu
# Out:
# Total columns: 307
#
# column names:
# ['Unnamed: 0', 'Year', 'CNT', 'CNTRYID', 'CNTSCHID', 'CNTSTUID', 'CYC', 'NatCen', 'STRATUM', 'SUBNATIO', 'OECD', 'ADMINMODE', 'LANGTEST_QQQ', 'LANGTEST_COG', 'LANGTEST_PAQ', 'Option_CT', 'Option_FL', 'Option_ICTQ', 'Option_WBQ', 'Option_PQ', 'Option_TQ', 'Option_UH', 'ST001D01T', 'ST003D02T', 'ST003D03T', 'ST004D01T', 'EFFORT1', 'EFFORT2', 'OCOD1', 'OCOD2', 'OCOD3', 'AGE', 'GRADE', 'ISCEDP', 'IMMIG', 'COBN_S', 'MISSSC', 'MATHEASE', 'WB153', 'ST253', 'ST311', 'WB165', 'IC171', 'ST038', 'IC180', 'ST255', 'ST350', 'ST034', 'FL162', 'PA195', 'ST330', 'FL169', 'ST230', 'ST331', 'ST354', 'PA042', 'ST305', 'ST258', 'PA167', 'IC176', 'ST352', 'IC173', 'PA188', 'ST283', 'ST256', 'WB154', 'WB166', 'FL150', 'ST266', 'IC174', 'ST005', 'ST021', 'IC182', 'FL164', 'FL160', 'ST267', 'ST338', 'ST351', 'ST342', 'ST355', 'FL166', 'PA183', 'ST007', 'FL170', 'WB168', 'WB163', 'IC184', 'ST348', 'ST226', 'ST336', 'WB160', 'FL167', 'PA166', 'ST250', 'ST268', 'IC177', 'PA196', 'IC183', 'ST275', 'IC172', 'IC175', 'ST340', 'ST296', 'ST270', 'ST289', 'ST353', 'ST349', 'ST301', 'PA186', 'WB164', 'PA197', 'ST290', 'ST062', 'ST254', 'ST345', 'ST322', 'IC170', 'PA006', 'ST347', 'ST343', 'ST307', 'ST160', 'ST168', 'ST161', 'ST153', 'ST188', 'PA009', 'PA182', 'PA004', 'ST059', 'ST150', 'PA158', 'WB155', 'WB162', 'ST127', 'EC162', 'ST104', 'PA003', 'ST125', 'ST163', 'ST297', 'ST006', 'ST263', 'PA162', 'ST164', 'ST008', 'ST152', 'EC031', 'WB177', 'ST183', 'EC012', 'ST223', 'ST177', 'ST102', 'PA041', 'EC163', 'PA008', 'PA177', 'ST175', 'ST273', 'EC153', 'ST212', 'PA154', 'PA156', 'PA007', 'PA159', 'ST300', 'ST036', 'PA018', 'ST208', 'ST165', 'PA175', 'ST167', 'ST211', 'WB176', 'ST158', 'WB178', 'IC014', 'ST213', 'ST327', 'ST251', 'ST260', 'PA160', 'ST095', 'PA033', 'ST146', 'ST098', 'ST100', 'ST097', 'ST113', 'PA002', 'PA032', 'IC001', 'ST008.1', 'ST006.1', 'PA008.1', 'ST011', 'reading_q1_average_score', 'reading_q2_average_score', 'reading_q3_average_score', 'reading_q4_average_score', 'reading_q5_average_score', 'reading_q6_average_score', 'reading_q7_average_score', 'reading_q8_average_score', 'reading_q9_average_score', 'reading_q10_average_score', 'reading_q11_average_score', 'reading_q12_average_score', 'reading_q13_average_score', 'reading_q14_average_score', 'reading_q15_average_score', 'math_q1_average_score', 'math_q2_average_score', 'math_q3_average_score', 'math_q4_average_score', 'math_q5_average_score', 'math_q6_average_score', 'math_q7_average_score', 'math_q8_average_score', 'math_q9_average_score', 'math_q10_average_score', 'math_q11_average_score', 'math_q12_average_score', 'math_q13_average_score', 'math_q14_average_score', 'math_q15_average_score', 'math_q16_average_score', 'math_q17_average_score', 'math_q18_average_score', 'math_q19_average_score', 'math_q20_average_score', 'math_q21_average_score', 'science_q1_average_score', 'science_q2_average_score', 'science_q3_average_score', 'science_q4_average_score', 'science_q5_average_score', 'science_q6_average_score', 'science_q7_average_score', 'science_q8_average_score', 'science_q9_average_score', 'science_q10_average_score', 'science_q11_average_score', 'science_q12_average_score', 'science_q13_average_score', 'science_q14_average_score', 'science_q15_average_score', 'science_q16_average_score', 'science_q17_average_score', 'science_q18_average_score', 'science_q19_average_score', 'reading_q1_total_timing', 'reading_q2_total_timing', 'reading_q3_total_timing', 'reading_q4_total_timing', 'reading_q5_total_timing', 'reading_q6_total_timing', 'reading_q7_total_timing', 'reading_q8_total_timing', 'reading_q9_total_timing', 'reading_q10_total_timing', 'reading_q11_total_timing', 'reading_q12_total_timing', 'reading_q13_total_timing', 'reading_q14_total_timing', 'reading_q15_total_timing', 'math_q1_total_timing', 'math_q2_total_timing', 'math_q3_total_timing', 'math_q4_total_timing', 'math_q5_total_timing', 'math_q6_total_timing', 'math_q7_total_timing', 'math_q8_total_timing', 'math_q9_total_timi ...
#
# Numeric columns: 304
# ['Unnamed: 0', 'Year', 'CNTRYID', 'CNTSCHID', 'CNTSTUID', 'NatCen', 'SUBNATIO', 'OECD', 'ADMINMODE', 'LANGTEST_QQQ']
#
# Categorical columns: 3
# ['CNT', 'CYC', 'STRATUM']

# %% [markdown]
# ### Missing Values Analysis

# %%
# Pourcentage de valeurs manquantes par colonne
missing_ratio = df.isnull().mean().sort_values(ascending=False)

# Affichage des colonnes les plus concernées
missing_cols = missing_ratio[missing_ratio > 0.0]
print(f"Columns with missing values: {len(missing_cols)}")

display(missing_cols.head(50))
# Out:
# Columns with missing values: 293
# science_q19_total_timing     1.000000
# reading_q15_total_timing     1.000000
# reading_q15_average_score    1.000000
# math_q18_average_score       1.000000
# math_q19_average_score       1.000000
# math_q20_average_score       1.000000
# math_q21_average_score       1.000000
# science_q13_average_score    1.000000
# science_q14_average_score    1.000000
# science_q15_average_score    1.000000
# science_q17_average_score    1.000000
# science_q18_average_score    1.000000
# science_q19_average_score    1.000000
# science_q16_average_score    1.000000
# science_q17_total_timing     1.000000
# science_q14_total_timing     1.000000
# science_q13_total_timing     1.000000
# science_q15_total_timing     1.000000
# science_q16_total_timing     1.000000
# math_q21_total_timing        1.000000
# science_q18_total_timing     1.000000
# math_q17_average_score       0.999998
# math_q18_total_timing        0.999998
# math_q17_total_timing        0.999998
# math_q20_total_timing        0.999998
# math_q19_total_timing        0.999998
# reading_q14_total_timing     0.999996
# reading_q14_average_score    0.999996
# reading_q13_average_score    0.999991
# reading_q13_total_timing     0.999989
# reading_q12_average_score    0.999976
# reading_q12_total_timing     0.999961
# reading_q11_average_score    0.999959
# reading_q11_total_timing     0.999911
# reading_q10_average_score    0.999372
# reading_q10_total_timing     0.999212
# math_q16_average_score       0.981168
# math_q16_total_timing        0.980334
# math_q15_average_score       0.971907
# math_q15_total_timing        0.970241
# science_q12_total_timing     0.961638
# science_q12_average_score    0.956807
# math_q14_average_score       0.925862
# math_q14_total_timing        0.924604
# reading_q9_average_score     0.919557
# reading_q9_total_timing      0.914335
# math_q13_average_score       0.846689
# math_q13_total_timing        0.843992
# LANGTEST_PAQ                 0.837966
# science_q11_total_timing     0.810043
# dtype: float64

# %% [markdown]
# ### Dropping Columns with Too Many Missing Values

# %%
# Drop columns with >90% missing values
high_missing_cols = missing_ratio[missing_ratio > 0.5].index.tolist()

print(f"Number of columns to drop: {len(high_missing_cols)}")

# Option 1: Drop
df_cleaned = df.drop(columns=high_missing_cols)

# Option 2 (Alternative): Save them separately if needed
# df_high_missing = df[high_missing_cols]

# New shape after removal
print("Shape after dropping high-missing columns:", df_cleaned.shape)
# Out:
# Number of columns to drop: 206
# Shape after dropping high-missing columns: (460398, 101)

# %% [markdown]
# ### Data Types Analysis

# %%
# Overview of data types
dtype_counts = df.dtypes.value_counts()
print("Data type distribution:")
display(dtype_counts)

# Show object columns (potential categoricals or misclassified numerics)
object_cols = df.select_dtypes(include='object').columns
print(f"\nNumber of 'object' columns: {len(object_cols)}")
display(object_cols)

# Look at unique value counts in object columns (to detect categorical candidates)
for col in object_cols:
    unique_vals = df[col].nunique(dropna=True)
    if unique_vals < 30:
        print(f" Categorical candidate: {col} ({unique_vals} unique values)")
    else:
        print(f" Non-categorical or needs inspection: {col} ({unique_vals} unique values)")
# Out:
# Data type distribution:
# float64    300
# int64        4
# object       3
# Name: count, dtype: int64
# Number of 'object' columns: 3
# Index(['CNT', 'CYC', 'STRATUM'], dtype='object')
#  Non-categorical or needs inspection: CNT (98 unique values)
#  Categorical candidate: CYC (3 unique values)
#  Non-categorical or needs inspection: STRATUM (2715 unique values)

# %% [markdown]
# ### Number of remaining columns

# %%
# Overview of column names and types in the cleaned dataset
print("Total columns:", len(df_cleaned.columns))

print("\nColumn names:")
print(df_cleaned.columns.tolist())

# Split into numerical and categorical columns
num_cols = df_cleaned.select_dtypes(include=["int64", "float64"]).columns.tolist()
cat_cols = df_cleaned.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

print(f"\nNumber of numerical columns: {len(num_cols)}")
print(num_cols[:10])  # preview

print(f"\nNumber of categorical columns: {len(cat_cols)}")
print(cat_cols[:10])  # preview
# Out:
# Total columns: 101
#
# Column names:
# ['Unnamed: 0', 'Year', 'CNT', 'CNTRYID', 'CNTSCHID', 'CNTSTUID', 'CYC', 'NatCen', 'STRATUM', 'SUBNATIO', 'OECD', 'ADMINMODE', 'LANGTEST_QQQ', 'LANGTEST_COG', 'Option_FL', 'Option_ICTQ', 'Option_PQ', 'Option_TQ', 'Option_UH', 'ST001D01T', 'ST003D02T', 'ST003D03T', 'ST004D01T', 'EFFORT1', 'EFFORT2', 'OCOD1', 'OCOD2', 'OCOD3', 'AGE', 'GRADE', 'IMMIG', 'COBN_S', 'WB165', 'IC171', 'ST038', 'ST255', 'ST034', 'PA042', 'IC173', 'WB154', 'IC174', 'ST005', 'ST021', 'PA183', 'ST007', 'WB163', 'PA166', 'ST250', 'ST296', 'ST270', 'ST353', 'ST349', 'WB164', 'ST062', 'ST254', 'IC170', 'reading_q1_average_score', 'reading_q2_average_score', 'reading_q3_average_score', 'reading_q4_average_score', 'reading_q5_average_score', 'reading_q6_average_score', 'math_q1_average_score', 'math_q2_average_score', 'math_q3_average_score', 'math_q4_average_score', 'math_q5_average_score', 'math_q6_average_score', 'math_q7_average_score', 'math_q8_average_score', 'math_q9_average_score', 'science_q1_average_score', 'science_q2_average_score', 'science_q3_average_score', 'science_q4_average_score', 'science_q5_average_score', 'science_q6_average_score', 'science_q7_average_score', 'science_q8_average_score', 'reading_q1_total_timing', 'reading_q2_total_timing', 'reading_q3_total_timing', 'reading_q4_total_timing', 'reading_q5_total_timing', 'reading_q6_total_timing', 'math_q1_total_timing', 'math_q2_total_timing', 'math_q3_total_timing', 'math_q4_total_timing', 'math_q5_total_timing', 'math_q6_total_timing', 'math_q7_total_timing', 'math_q8_total_timing', 'math_q9_total_timing', 'science_q1_total_timing', 'science_q2_total_timing', 'science_q3_total_timing', 'science_q4_total_timing', 'science_q5_total_timing', 'science_q6_total_timing', 'science_q7_total_timing']
#
# Number of numerical columns: 98
# ['Unnamed: 0', 'Year', 'CNTRYID', 'CNTSCHID', 'CNTSTUID', 'NatCen', 'SUBNATIO', 'OECD', 'ADMINMODE', 'LANGTEST_QQQ']
#
# Number of categorical columns: 3
# ['CNT', 'CYC', 'STRATUM']

# %% [markdown]
# ### Imputing Missing Values with Column Mean

# %%
# Impute missing values with column means (numerical only)
df_cleaned = df_cleaned.copy()  # create a safe copy

# Only apply mean imputation on numerical columns
num_cols = df_cleaned.select_dtypes(include=["float64", "int64"]).columns

df_cleaned[num_cols] = df_cleaned[num_cols].fillna(df_cleaned[num_cols].mean())

# Confirm remaining missing values
missing_total = df_cleaned.isnull().sum().sum()
print(f"Remaining missing values: {missing_total}")
# Out:
# Remaining missing values: 0

# %% [markdown]
# ### Outlier Detection and Exploration

# %%
# Sélection des colonnes mathématiques avec "average_score"
math_score_cols = [col for col in df_cleaned.columns if "math" in col and "average_score" in col]

# Affichage de boxplots pour voir les éventuels outliers
plt.figure(figsize=(16, 10))
df_cleaned[math_score_cols].boxplot()
plt.title("Boxplots of Math Average Scores")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Nettoyage des colonnes catégorielles

# %% [markdown]
# ### Standardiser les chaînes de caractères

# %%
# On repart de df_cleaned
df_cat_cleaned = df_cleaned.copy()

# Standardiser les colonnes catégorielles : strip, lowercase
for col in df_cat_cleaned.select_dtypes(include=["object", "category"]).columns:
    df_cat_cleaned[col] = df_cat_cleaned[col].astype(str).str.strip().str.lower()

print("Standardisation terminée.")
# Out:
# Standardisation terminée.

# %% [markdown]
# ### Visualiser la cardinalité de chaque colonne

# %%
# Aperçu des colonnes avec leur nombre de catégories uniques
cat_cols = df_cat_cleaned.select_dtypes(include=["object", "category"]).columns

for col in cat_cols:
    print(f"{col}: {df_cat_cleaned[col].nunique()} unique values")
# Out:
# CNT: 98 unique values
# CYC: 3 unique values
# STRATUM: 2715 unique values

# %% [markdown]
# ### Détecter et regrouper les catégories rares

# %%
# Fonction pour regrouper les catégories rares en "other"
def group_rare_categories(df, col, threshold=0.01):
    freq = df[col].value_counts(normalize=True)
    rare_labels = freq[freq < threshold].index
    df[col] = df[col].apply(lambda x: "other" if x in rare_labels else x)
    return df

# Application sur toutes les colonnes catégorielles
for col in cat_cols:
    df_cat_cleaned = group_rare_categories(df_cat_cleaned, col)

print("Rare categories regrouped as 'other'.")
# Out:
# Rare categories regrouped as 'other'.

# %% [markdown]
# ## Step 4 – Feature Engineering (Part 1): Skewness Analysis and Log Transformation
#
# In this step, we explore and transform highly skewed numerical features.
#
# - Skewed features can negatively impact model performance.
# - A log transformation can help normalize the distribution of such features.
# - We only apply log(1+x) to positively skewed features to preserve interpretability.
#
# We start by calculating the skewness for each numerical column and then apply log transformation to those with skewness > 1.

# %%
from scipy.stats import skew

# Select numeric columns
num_cols = df_cat_cleaned.select_dtypes(include=["float64", "int64"]).columns

# Compute skewness
skewed_feats = df_cat_cleaned[num_cols].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)

# Display top 10 most skewed features
print("Top 10 skewed features:")
display(skewed_feats.head(10))
# Out:
# Top 10 skewed features:
# math_q6_total_timing       502.214693
# math_q9_total_timing       447.770351
# science_q7_total_timing    235.246206
# math_q1_total_timing       167.560469
# science_q3_total_timing    146.619012
# science_q1_total_timing    144.521919
# math_q7_total_timing       140.553130
# math_q4_total_timing       124.461915
# math_q5_total_timing       111.913757
# math_q3_total_timing       110.211931
# dtype: float64

# %% [markdown]
# ## Log Transformation on Highly Skewed Features
#
# We apply a log(1+x) transformation on features with a skewness greater than 1.
#
# This will help reduce the skewness and make the data more normally distributed, which improves the performance of models sensitive to feature distributions.

# %%
# Identify skewed features with skewness > 1
skewed_features = skewed_feats[skewed_feats > 1].index

# Make a copy of the cleaned dataframe
df_transformed = df_cat_cleaned.copy()

# Apply log1p (log(1 + x)) transformation
df_transformed[skewed_features] = df_transformed[skewed_features].apply(lambda x: np.log1p(x))

print(f"Log transformation applied to {len(skewed_features)} features.")
# Out:
# Log transformation applied to 47 features.

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold

# Filter only numeric columns before applying VarianceThreshold
numeric_df = df_transformed.select_dtypes(include=["int64", "float64"])

# Step 1: Remove constant and quasi-constant features
selector = VarianceThreshold(threshold=0.01)
selector.fit(numeric_df)

# Get columns to keep
features_to_keep = numeric_df.columns[selector.get_support()]
print(f"Remaining features after removing constant/quasi-constant: {len(features_to_keep)}")

# Update the dataframe
df_final = df_transformed[features_to_keep]

# Final shape
print(f"Final shape of the dataset after feature selection: {df_final.shape}")
# Out:
# Remaining features after removing constant/quasi-constant: 96
# Final shape of the dataset after feature selection: (460398, 96)

# %% [markdown]
# ### Load and Analyze the Target Variable `MathScore`

# %%
# Load target variable
y_train_path = "y_train.csv"  
y_train = pd.read_csv(y_train_path)

# Display the first few rows
print("First rows of y_train:")
display(y_train.head())

# Check column name(s)
print("\n Columns in y_train:", y_train.columns.tolist())

# Check basic info
print("\nInfo:")
y_train.info()

# Summary statistics
print("\nStatistical summary:")
display(y_train.describe())

# Check missing values
missing = y_train.isnull().sum().values[0]
print(f"\n Missing values in y_train: {missing}")
# Out:
# First rows of y_train:
#    Unnamed: 0   MathScore
# 0      384002  116.975422
# 1     1118072   73.387560
# 2      845454    0.000000
# 3     1728613    0.000000
# 4     1083243  113.750718
#  Columns in y_train: ['Unnamed: 0', 'MathScore']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172086 entries, 0 to 1172085
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1172086 non-null  int64
#  1   MathScore   1172086 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 17.9 MB
#
# Statistical summary:
#          Unnamed: 0     MathScore
# count  1.172086e+06  1.172086e+06
# mean   8.788127e+05  9.999513e+01
# std    5.075340e+05  1.221761e+02
# min    0.000000e+00  0.000000e+00
# 25%    4.390612e+05  0.000000e+00
# 50%    8.787835e+05  6.604880e+01
# 75%    1.318404e+06  1.528073e+02
# max    1.758128e+06  8.149725e+02
#  Missing values in y_train: 0

# %% [markdown]
# ### Visual Inspection of the `MathScore` Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check column name of target
print("Target column:", y_train.columns.tolist())

# Target variable
target_col = y_train.columns[1] if "Unnamed: 0" in y_train.columns else y_train.columns[0]

plt.figure(figsize=(16, 5))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(y_train[target_col], bins=50, kde=True, color='skyblue')
plt.title("Distribution of MathScore")
plt.xlabel("MathScore")
plt.ylabel("Frequency")

# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(x=y_train[target_col], color='orange')
plt.title("Boxplot of MathScore")
plt.xlabel("MathScore")

plt.tight_layout()
plt.show()
# Out:
# Target column: ['Unnamed: 0', 'MathScore']

# %% [markdown]
# ### Cleaning the Target Variable (`MathScore`)

# %%
# Threshold to filter out impossible or unrealistic scores
upper_limit = 800

# Check original shape
print(f"Original y_train shape: {y_train.shape}")

# Keep only values within realistic bounds (0 <= score <= 120)
y_train_cleaned = y_train[(y_train["MathScore"] >= 0) & (y_train["MathScore"] <= upper_limit)]

# Check cleaned shape
print(f"Cleaned y_train shape: {y_train_cleaned.shape}")
# Out:
# Original y_train shape: (1172086, 2)
# Cleaned y_train shape: (1172048, 2)

# %% [markdown]
# ### Aligning Features and Target
#
# To ensure accurate correlation analysis between features and the target (`MathScore`), we align the cleaned features (`X_train`) with the target values (`y_train`) based on their shared identifier `Unnamed: 0`, which we renamed to `ID`.

# %%
# 🔁 Step 1: Rename and set index for alignment (based on ID)
df_final = df_final.rename(columns={"Unnamed: 0": "ID"}).set_index("ID")
y_train = y_train.rename(columns={"Unnamed: 0": "ID"}).set_index("ID")

#  Step 2: Align feature DataFrame and target DataFrame on ID
X_aligned, y_aligned = df_final.align(y_train, join="inner", axis=0)

# Optional: check the resulting shapes
print(f" Aligned features (X_aligned) shape: {X_aligned.shape}")
print(f" Aligned target (y_aligned) shape: {y_aligned.shape}")

# Optionally: check if index alignment was successful
print(f" Common IDs: {X_aligned.index.equals(y_aligned.index)}")
# Out:
#  Aligned features (X_aligned) shape: (460398, 95)
#  Aligned target (y_aligned) shape: (460398, 1)
#  Common IDs: True

# %% [markdown]
# ### Correlation Analysis
#
# Now that we have a unified target variable `MathScore`, we proceed to analyze the correlation between this target and the input features.
#
# This helps us:
# - Understand which variables are most predictive of math performance.
# - Detect multicollinearity between features.
# - Optionally drop highly correlated variables (if redundant).
#
# We will:
# - Compute Pearson correlation.
# - Visualize the correlation matrix (heatmap).
# - Plot top 20 features most correlated with `MathScore`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combine features and target into one DataFrame
df_corr = pd.concat([X_aligned, y_aligned], axis=1)

# Check the actual name of the target column
target_col = y_aligned.columns[0]

# Compute correlation matrix (numeric only)
corr_matrix = df_corr.corr(numeric_only=True)

# Correlation with target
target_corr = corr_matrix[target_col].drop(target_col)

# Top 20 most correlated features (absolute values)
top_corr = target_corr.abs().sort_values(ascending=False).head(20)

# Display actual (signed) correlations
print("Top 20 features most correlated with target:")
display(target_corr[top_corr.index].sort_values(ascending=False))

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(df_corr[top_corr.index.tolist() + [target_col]].corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title(f"Correlation Heatmap – Top 20 Features vs {target_col}")
plt.tight_layout()
plt.show()
# Out:
# Top 20 features most correlated with target:
# math_q2_average_score       0.337212
# math_q3_average_score       0.323545
# math_q1_average_score       0.290168
# math_q7_average_score       0.286919
# math_q8_average_score       0.259470
# math_q9_average_score       0.258474
# math_q5_average_score       0.253573
# math_q6_average_score       0.252722
# math_q4_average_score       0.229418
# ST255                       0.137084
# reading_q3_average_score    0.121558
# reading_q6_average_score    0.120841
# reading_q4_average_score    0.116925
# reading_q5_average_score    0.116487
# OECD                        0.116337
# science_q6_average_score    0.113804
# science_q5_average_score    0.110360
# reading_q1_average_score    0.105029
# science_q4_average_score    0.104537
# science_q3_total_timing     0.101930
# Name: MathScore, dtype: float64

# %% [markdown]
# ### Principal Component Analysis (PCA) – Optional Step
#
# If we observe:
# - Strong multicollinearity between features
# - A very large number of features that may affect model generalization
#
# We may apply **PCA** (Principal Component Analysis) to:
# - Reduce the number of features
# - Preserve maximum variance
# - Speed up model training
#
# We will standardize the data before applying PCA and plot the explained variance ratio.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_aligned)

# Apply PCA
pca = PCA(n_components=30)  # You can adjust based on how much variance you want to explain
X_pca = pca.fit_transform(X_scaled)

# Plot cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by PCA Components')
plt.grid(True)
plt.axhline(0.90, color='r', linestyle='--', label='90% Threshold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

# Step 1: Get the absolute value of loadings (feature contributions)
loadings = np.abs(pca.components_)

# Step 2: Sum contributions of each feature across all components
feature_importance = loadings.sum(axis=0)

# Step 3: Map back to original feature names
feature_names = X_aligned.columns
importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": feature_importance
}).sort_values(by="importance", ascending=False)

# Step 4: Decide threshold (e.g., keep top 70% most important features)
top_k = int(len(importance_df) * 0.7)
important_features = importance_df["feature"].head(top_k).tolist()

# Step 5: Reduce X_aligned accordingly
X_reduced = X_aligned[important_features]

print(f"Reduced feature set from {X_aligned.shape[1]} to {X_reduced.shape[1]} features.")
# Out:
# Reduced feature set from 95 to 66 features.

# %% [markdown]
# ## Step 9 – Smart Train-Test Split
#
# We now split our dataset into training and testing sets to evaluate model performance.
# Key considerations:
#
# - We use stratified sampling if the target is categorical to ensure class balance.
# - In our case, since `MathScore` is continuous (regression task), we will perform a standard split.
# - We'll reserve 20% of the data for testing.

# %%
from sklearn.model_selection import train_test_split

# Perform the split: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(
    X_aligned, y_aligned, test_size=0.2, random_state=42
)

# Confirm the resulting shapes
print("Shapes after train-test split:")
print("X_train shape:", X_train.shape)
print("X_test shape :", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape :", y_test.shape)
# Out:
# Shapes after train-test split:
# X_train shape: (368318, 95)
# X_test shape : (92080, 95)
# y_train shape: (368318, 1)
# y_test shape : (92080, 1)

# %% [markdown]
# ## Step 10 – Linear Regression Model
#
# We start with a basic Linear Regression model as a benchmark. We'll fit the model and evaluate it using:
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Initialize and train model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Predict
y_pred_lr = lr_model.predict(X_test)

# Evaluation metrics
mae = mean_absolute_error(y_test, y_pred_lr)
mse = mean_squared_error(y_test, y_pred_lr)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_lr)

print("🔍 Linear Regression Results:")
print(f"MAE  : {mae:.4f}")
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# 🔍 Linear Regression Results:
# MAE  : 79.2188
# MSE  : 9423.9455
# RMSE : 97.0770
# R²   : 0.3700

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Train model
rf_model = RandomForestRegressor(n_estimators=100, max_depth=None, random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred_rf = rf_model.predict(X_test)

# Metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# Display
print("\n Random Forest Regressor Results:")
print(f"MAE  : {mae_rf:.4f}")
print(f"MSE  : {mse_rf:.4f}")
print(f"RMSE : {rmse_rf:.4f}")
print(f"R²   : {r2_rf:.4f}")

# %% [markdown]
# ### XGBoost Regressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Train model
xgb_model = XGBRegressor(n_estimators=100, max_depth=6, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)

# Predict
y_pred_xgb = xgb_model.predict(X_test)

# Metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

# Display
print("📈 XGBoost Regressor Results:")
print(f"MAE  : {mae_xgb:.4f}")
print(f"MSE  : {mse_xgb:.4f}")
print(f"RMSE : {rmse_xgb:.4f}")
print(f"R²   : {r2_xgb:.4f}")
